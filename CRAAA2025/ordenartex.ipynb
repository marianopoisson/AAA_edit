# %%
import os
import re

# %%
# Directorio donde se encuentran los archivos
directorio = "./corregidos"

# Iterar sobre los archivos en el directorio
for nombre_archivo in os.listdir(directorio):
    # Buscar archivos que sigan el patrón ####_v*.tex
    coincidencia = re.match(r'(\d{4})_v\d+corr.tex', nombre_archivo)
    
    if coincidencia:
        # Extraer el número ####
        nuevo_nombre = coincidencia.group(1) + ".tex"
        ruta_vieja = os.path.join(directorio, nombre_archivo)
        ruta_nueva = os.path.join(directorio, nuevo_nombre)
        
        # Renombrar el archivo
        os.rename(ruta_vieja, ruta_nueva)
        print(f"Renombrado: {nombre_archivo} -> {nuevo_nombre}")

print("Proceso completado.")
# Out:
# Renombrado: 2093_v1corr.tex -> 2093.tex
# Renombrado: 2094_v3corr.tex -> 2094.tex
# Renombrado: 2101_v1corr.tex -> 2101.tex
# Renombrado: 2104_v1corr.tex -> 2104.tex
# Renombrado: 2106_v1corr.tex -> 2106.tex
# Renombrado: 2112_v1corr.tex -> 2112.tex
# Renombrado: 2121_v1corr.tex -> 2121.tex
# Renombrado: 2138_v1corr.tex -> 2138.tex
# Renombrado: 2155_v2corr.tex -> 2155.tex
# Renombrado: 2158_v1corr.tex -> 2158.tex
# Renombrado: 2171_v1corr.tex -> 2171.tex
# Renombrado: 2177_v1corr.tex -> 2177.tex
# Renombrado: 2188_v1corr.tex -> 2188.tex
# Renombrado: 2189_v1corr.tex -> 2189.tex
# Renombrado: 2229_v1corr.tex -> 2229.tex
# Renombrado: 2236_v1corr.tex -> 2236.tex
# Renombrado: 2238_v1corr.tex -> 2238.tex
# Renombrado: 2248_v1corr.tex -> 2248.tex
# Renombrado: 2250_v2corr.tex -> 2250.tex
# Renombrado: 2257_v1corr.tex -> 2257.tex
# Renombrado: 2265_v1corr.tex -> 2265.tex
# Renombrado: 2266_v2corr.tex -> 2266.tex
# Renombrado: 2267_v1corr.tex -> 2267.tex
# Renombrado: 2269_v1corr.tex -> 2269.tex
# Renombrado: 2271_v1corr.tex -> 2271.tex
# Renombrado: 2272_v2corr.tex -> 2272.tex
# Renombrado: 2273_v1corr.tex -> 2273.tex
# Renombrado: 2293_v1corr.tex -> 2293.tex
# Renombrado: 2305_v1corr.tex -> 2305.tex
# Renombrado: 2314_v1corr.tex -> 2314.tex
# Proceso completado.

# %%
import os
import shutil

# Directorios de origen y destino
directorio_origen = "./tex"
directorio_destino = "./tex2"

# Ruta del archivo lista.txt
ruta_lista = "listamurales.txt"

# Leer los números de archivos desde lista.txt
with open(ruta_lista, 'r') as archivo_lista:
    numeros_a_copiar = [linea.strip() for linea in archivo_lista.readlines()]

# Copiar los archivos listados en lista.txt
for numero in numeros_a_copiar:
    nombre_archivo = f"{numero}.tex"
    ruta_origen = os.path.join(directorio_origen, nombre_archivo)
    ruta_destino = os.path.join(directorio_destino, nombre_archivo)
    
    # Verificar si el archivo existe antes de copiar
    if os.path.exists(ruta_origen):
        # Copiar el archivo
        shutil.copy(ruta_origen, ruta_destino)
        print(f"Copiado: {nombre_archivo} a {ruta_destino}")
    else:
        print(f"El archivo {nombre_archivo} no existe en el directorio de origen.")

print("Proceso completado.")
# Out:
# Copiado: 2162.tex a ./tex2\2162.tex
# Copiado: 2090.tex a ./tex2\2090.tex
# Copiado: 2279.tex a ./tex2\2279.tex
# Copiado: 2156.tex a ./tex2\2156.tex
# Copiado: 2296.tex a ./tex2\2296.tex
# Copiado: 2186.tex a ./tex2\2186.tex
# Copiado: 2102.tex a ./tex2\2102.tex
# Copiado: 2157.tex a ./tex2\2157.tex
# Copiado: 2158.tex a ./tex2\2158.tex
# Copiado: 2086.tex a ./tex2\2086.tex
# Copiado: 2098.tex a ./tex2\2098.tex
# Copiado: 2177.tex a ./tex2\2177.tex
# Copiado: 2213.tex a ./tex2\2213.tex
# Copiado: 2312.tex a ./tex2\2312.tex
# Copiado: 2268.tex a ./tex2\2268.tex
# Copiado: 2216.tex a ./tex2\2216.tex
# Copiado: 2096.tex a ./tex2\2096.tex
# Copiado: 2161.tex a ./tex2\2161.tex
# Copiado: 2224.tex a ./tex2\2224.tex
# Copiado: 2255.tex a ./tex2\2255.tex
# Copiado: 2176.tex a ./tex2\2176.tex
# Copiado: 2293.tex a ./tex2\2293.tex
# Copiado: 2125.tex a ./tex2\2125.tex
# Copiado: 2188.tex a ./tex2\2188.tex
# Copiado: 2076.tex a ./tex2\2076.tex
# Copiado: 2172.tex a ./tex2\2172.tex
# Copiado: 2284.tex a ./tex2\2284.tex
# Copiado: 2273.tex a ./tex2\2273.tex
# Copiado: 2230.tex a ./tex2\2230.tex
# Copiado: 2309.tex a ./tex2\2309.tex
# Copiado: 2285.tex a ./tex2\2285.tex
# Copiado: 2249.tex a ./tex2\2249.tex
# Copiado: 2152.tex a ./tex2\2152.tex
# Copiado: 2168.tex a ./tex2\2168.tex
# Copiado: 2210.tex a ./tex2\2210.tex
# Copiado: 2138.tex a ./tex2\2138.tex
# Copiado: 2265.tex a ./tex2\2265.tex
# Copiado: 2227.tex a ./tex2\2227.tex
# Copiado: 2272.tex a ./tex2\2272.tex
# Copiado: 2290.tex a ./tex2\2290.tex
# Copiado: 2127.tex a ./tex2\2127.tex
# Copiado: 2253.tex a ./tex2\2253.tex
# Copiado: 2228.tex a ./tex2\2228.tex
# Copiado: 2160.tex a ./tex2\2160.tex
# Copiado: 2209.tex a ./tex2\2209.tex
# Copiado: 2298.tex a ./tex2\2298.tex
# Copiado: 2257.tex a ./tex2\2257.tex
# Copiado: 2211.tex a ./tex2\2211.tex
# Copiado: 2143.tex a ./tex2\2143.tex
# Copiado: 2299.tex a ./tex2\2299.tex
# Copiado: 2142.tex a ./tex2\2142.tex
# Copiado: 2122.tex a ./tex2\2122.tex
# Copiado: 2091.tex a ./tex2\2091.tex
# Copiado: 2148.tex a ./tex2\2148.tex
# Copiado: 2082.tex a ./tex2\2082.tex
# Copiado: 2260.tex a ./tex2\2260.tex
# Copiado: 2215.tex a ./tex2\2215.tex
# Copiado: 2087.tex a ./tex2\2087.tex
# Copiado: 2180.tex a ./tex2\2180.tex
# Copiado: 2080.tex a ./tex2\2080.tex
# Copiado: 2306.tex a ./tex2\2306.tex
# Copiado: 2258.tex a ./tex2\2258.tex
# Copiado: 2119.tex a ./tex2\2119.tex
# Copiado: 2167.tex a ./tex2\2167.tex
# Copiado: 2100.tex a ./tex2\2100.tex
# Copiado: 2194.tex a ./tex2\2194.tex
# Copiado: 2235.tex a ./tex2\2235.tex
# Copiado: 2146.tex a ./tex2\2146.tex
# Copiado: 2263.tex a ./tex2\2263.tex
# Copiado: 2223.tex a ./tex2\2223.tex
# Copiado: 2155.tex a ./tex2\2155.tex
# Copiado: 2311.tex a ./tex2\2311.tex
# Copiado: 2297.tex a ./tex2\2297.tex
# Copiado: 2212.tex a ./tex2\2212.tex
# Copiado: 2200.tex a ./tex2\2200.tex
# Copiado: 2104.tex a ./tex2\2104.tex
# Copiado: 2304.tex a ./tex2\2304.tex
# Copiado: 2305.tex a ./tex2\2305.tex
# Copiado: 2240.tex a ./tex2\2240.tex
# Copiado: 2092.tex a ./tex2\2092.tex
# Copiado: 2139.tex a ./tex2\2139.tex
# Copiado: 2229.tex a ./tex2\2229.tex
# Copiado: 2236.tex a ./tex2\2236.tex
# Copiado: 2303.tex a ./tex2\2303.tex
# Copiado: 2085.tex a ./tex2\2085.tex
# Copiado: 2274.tex a ./tex2\2274.tex
# Copiado: 2084.tex a ./tex2\2084.tex
# Copiado: 2190.tex a ./tex2\2190.tex
# Copiado: 2174.tex a ./tex2\2174.tex
# Copiado: 2189.tex a ./tex2\2189.tex
# Copiado: 2202.tex a ./tex2\2202.tex
# Copiado: 2201.tex a ./tex2\2201.tex
# Copiado: 2150.tex a ./tex2\2150.tex
# Copiado: 2105.tex a ./tex2\2105.tex
# Copiado: 2267.tex a ./tex2\2267.tex
# Copiado: 2159.tex a ./tex2\2159.tex
# Copiado: 2115.tex a ./tex2\2115.tex
# Copiado: 2169.tex a ./tex2\2169.tex
# Copiado: 2276.tex a ./tex2\2276.tex
# Copiado: 2278.tex a ./tex2\2278.tex
# Copiado: 2203.tex a ./tex2\2203.tex
# Copiado: 2185.tex a ./tex2\2185.tex
# Copiado: 2256.tex a ./tex2\2256.tex
# Copiado: 2170.tex a ./tex2\2170.tex
# Copiado: 2205.tex a ./tex2\2205.tex
# Copiado: 2271.tex a ./tex2\2271.tex
# Copiado: 2195.tex a ./tex2\2195.tex
# Copiado: 2292.tex a ./tex2\2292.tex
# Copiado: 2288.tex a ./tex2\2288.tex
# Proceso completado.

# %%
# Directorio donde se encuentran los archivos
directorio = "./corregidos"

# Diccionario para almacenar la versión más alta de cada número base ####
archivos_por_numero = {}

# Iterar sobre los archivos en el directorio
for nombre_archivo in os.listdir(directorio):
    # Buscar archivos que sigan el patrón ####_v*.tex
    coincidencia = re.match(r'(\d{4})_v(\d+)\.tex', nombre_archivo)
    
    if coincidencia:
        numero_base = coincidencia.group(1)  # ####
        version = int(coincidencia.group(2))  # versión numérica v*

        # Si no existe un archivo para ese número o si la versión es mayor, actualizamos
        if numero_base not in archivos_por_numero or archivos_por_numero[numero_base][1] < version:
            archivos_por_numero[numero_base] = (nombre_archivo, version)

# Renombrar solo los archivos con la versión más alta
for numero_base, (nombre_archivo, version) in archivos_por_numero.items():
    nuevo_nombre = numero_base + ".tex"
    ruta_vieja = os.path.join(directorio, nombre_archivo)
    ruta_nueva = os.path.join(directorio, nuevo_nombre)
    
    # Renombrar el archivo
    os.rename(ruta_vieja, ruta_nueva)
    print(f"Renombrado: {nombre_archivo} -> {nuevo_nombre}")

print("Proceso completado.")
# Out:
# Proceso completado.

# %%
import os

# Directorio donde se encuentran los archivos .tex
directorio = "./tex1"

# Ruta del archivo lista.txt que contiene los nombres de los archivos .tex
ruta_lista = "./listaorales.txt"

# Leer los números de archivos desde lista.txt
with open(ruta_lista, 'r') as archivo_lista:
    archivos_a_revisar = [linea.strip() + ".tex" for linea in archivo_lista.readlines()]

# Iterar sobre los archivos listados
for nombre_archivo in archivos_a_revisar:
    ruta_archivo = os.path.join(directorio, nombre_archivo)
    
    # Verificar si el archivo existe
    if os.path.exists(ruta_archivo):
        # Leer el contenido del archivo
        with open(ruta_archivo, 'r') as archivo:
            contenido = archivo.read()

        # Revisar si contiene \contribtype{1} y reemplazarlo por \contribtype{2}
        if r"\contribtype{1}" in contenido:
            contenido_nuevo = contenido.replace(r"\contribtype{1}", r"\contribtype{2}")
            
            # Guardar los cambios en el archivo
            with open(ruta_archivo, 'w') as archivo:
                archivo.write(contenido_nuevo)
            
            print(f"Modificado: {nombre_archivo} - \contribtype{1} cambiado a \contribtype{2}")
        else:
            print(f"Sin cambios: {nombre_archivo} - No contiene \contribtype{{1}}")
    else:
        print(f"El archivo {nombre_archivo} no existe.")

print("Proceso completado.")
# Out:
# <>:31: SyntaxWarning: invalid escape sequence '\c'
# <>:31: SyntaxWarning: invalid escape sequence '\c'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# <>:31: SyntaxWarning: invalid escape sequence '\c'
# <>:31: SyntaxWarning: invalid escape sequence '\c'
# <>:33: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:31: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{1} cambiado a \contribtype{2}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:31: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{1} cambiado a \contribtype{2}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:33: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Sin cambios: {nombre_archivo} - No contiene \contribtype{{1}}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:31: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{1} cambiado a \contribtype{2}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:31: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{1} cambiado a \contribtype{2}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\541169587.py:33: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Sin cambios: {nombre_archivo} - No contiene \contribtype{{1}}")
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[11], line 21
#      18 if os.path.exists(ruta_archivo):
#      19     # Leer el contenido del archivo
#      20     with open(ruta_archivo, 'r') as archivo:
# ---> 21         contenido = archivo.read()
#      23     # Revisar si contiene \contribtype{1} y reemplazarlo por \contribtype{2}
#      24     if r"\contribtype{1}" in contenido:
#
# File ~\anaconda3\envs\editor\Lib\encodings\cp1252.py:23, in IncrementalDecoder.decode(self, input, final)
#      22 def decode(self, input, final=False):
# ---> 23     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 5401: character maps to <undefined>

# %%
import os

# Directorio donde se encuentran los archivos .tex
directorio = "./tex2"

# Ruta del archivo lista.txt que contiene los nombres de los archivos .tex
ruta_lista = "./listamurales.txt"

# Leer los números de archivos desde lista.txt
with open(ruta_lista, 'r', encoding='utf-8') as archivo_lista:
    archivos_a_revisar = [linea.strip() + ".tex" for linea in archivo_lista.readlines()]

# Iterar sobre los archivos listados
for nombre_archivo in archivos_a_revisar:
    ruta_archivo = os.path.join(directorio, nombre_archivo)
    
    # Verificar si el archivo existe
    if os.path.exists(ruta_archivo):
        try:
            # Leer el contenido del archivo usando utf-8
            with open(ruta_archivo, 'r', encoding='utf-8') as archivo:
                contenido = archivo.read()

            # Revisar si contiene \contribtype{1} y reemplazarlo por \contribtype{2}
            if r"\contribtype{2}" in contenido:
                contenido_nuevo = contenido.replace(r"\contribtype{2}", r"\contribtype{1}")
                
                # Guardar los cambios en el archivo usando utf-8
                with open(ruta_archivo, 'w', encoding='utf-8') as archivo:
                    archivo.write(contenido_nuevo)
                
                print(f"Modificado: {nombre_archivo} - \contribtype{{2}} cambiado a \contribtype{{1}}")
            else:
                print(f"Sin cambios: {nombre_archivo} - No contiene \contribtype{{2}}")
        except UnicodeDecodeError as e:
            print(f"Error de codificación al leer {nombre_archivo}: {e}")
    else:
        print(f"El archivo {nombre_archivo} no existe.")

print("Proceso completado.")
# Out:
# Modificado: 2162.tex - \contribtype{2} cambiado a \contribtype{1}
# Modificado: 2090.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2279.tex - No contiene \contribtype{2}
# Modificado: 2156.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2296.tex - No contiene \contribtype{2}
# Sin cambios: 2186.tex - No contiene \contribtype{2}
# Sin cambios: 2102.tex - No contiene \contribtype{2}
# Sin cambios: 2157.tex - No contiene \contribtype{2}
# Sin cambios: 2158.tex - No contiene \contribtype{2}
# Sin cambios: 2086.tex - No contiene \contribtype{2}
# Sin cambios: 2098.tex - No contiene \contribtype{2}
# Sin cambios: 2177.tex - No contiene \contribtype{2}
# Sin cambios: 2213.tex - No contiene \contribtype{2}
# Sin cambios: 2312.tex - No contiene \contribtype{2}
# Sin cambios: 2268.tex - No contiene \contribtype{2}
# Sin cambios: 2216.tex - No contiene \contribtype{2}
# Sin cambios: 2096.tex - No contiene \contribtype{2}
# Sin cambios: 2161.tex - No contiene \contribtype{2}
# Sin cambios: 2224.tex - No contiene \contribtype{2}
# Sin cambios: 2255.tex - No contiene \contribtype{2}
# Modificado: 2176.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2293.tex - No contiene \contribtype{2}
# Sin cambios: 2125.tex - No contiene \contribtype{2}
# Sin cambios: 2188.tex - No contiene \contribtype{2}
# Sin cambios: 2076.tex - No contiene \contribtype{2}
# Sin cambios: 2172.tex - No contiene \contribtype{2}
# Sin cambios: 2284.tex - No contiene \contribtype{2}
# Sin cambios: 2273.tex - No contiene \contribtype{2}
# Sin cambios: 2230.tex - No contiene \contribtype{2}
# Sin cambios: 2309.tex - No contiene \contribtype{2}
# Sin cambios: 2285.tex - No contiene \contribtype{2}
# Sin cambios: 2249.tex - No contiene \contribtype{2}
# Sin cambios: 2152.tex - No contiene \contribtype{2}
# Sin cambios: 2168.tex - No contiene \contribtype{2}
# Sin cambios: 2210.tex - No contiene \contribtype{2}
# Sin cambios: 2138.tex - No contiene \contribtype{2}
# Sin cambios: 2265.tex - No contiene \contribtype{2}
# Sin cambios: 2227.tex - No contiene \contribtype{2}
# Sin cambios: 2272.tex - No contiene \contribtype{2}
# Sin cambios: 2290.tex - No contiene \contribtype{2}
# Sin cambios: 2127.tex - No contiene \contribtype{2}
# Sin cambios: 2253.tex - No contiene \contribtype{2}
# Sin cambios: 2228.tex - No contiene \contribtype{2}
# Sin cambios: 2160.tex - No contiene \contribtype{2}
# Sin cambios: 2209.tex - No contiene \contribtype{2}
# Sin cambios: 2298.tex - No contiene \contribtype{2}
# Sin cambios: 2257.tex - No contiene \contribtype{2}
# Sin cambios: 2211.tex - No contiene \contribtype{2}
# Sin cambios: 2143.tex - No contiene \contribtype{2}
# Sin cambios: 2299.tex - No contiene \contribtype{2}
# Modificado: 2142.tex - \contribtype{2} cambiado a \contribtype{1}
# Modificado: 2122.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2091.tex - No contiene \contribtype{2}
# Sin cambios: 2148.tex - No contiene \contribtype{2}
# Sin cambios: 2082.tex - No contiene \contribtype{2}
# Sin cambios: 2260.tex - No contiene \contribtype{2}
# Sin cambios: 2215.tex - No contiene \contribtype{2}
# Sin cambios: 2087.tex - No contiene \contribtype{2}
# Sin cambios: 2180.tex - No contiene \contribtype{2}
# Sin cambios: 2080.tex - No contiene \contribtype{2}
# Modificado: 2306.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2258.tex - No contiene \contribtype{2}
# Sin cambios: 2119.tex - No contiene \contribtype{2}
# Sin cambios: 2167.tex - No contiene \contribtype{2}
# Sin cambios: 2100.tex - No contiene \contribtype{2}
# Sin cambios: 2194.tex - No contiene \contribtype{2}
# Sin cambios: 2235.tex - No contiene \contribtype{2}
# Sin cambios: 2146.tex - No contiene \contribtype{2}
# Sin cambios: 2263.tex - No contiene \contribtype{2}
# Modificado: 2223.tex - \contribtype{2} cambiado a \contribtype{1}
# Modificado: 2155.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2311.tex - No contiene \contribtype{2}
# Sin cambios: 2297.tex - No contiene \contribtype{2}
# Sin cambios: 2212.tex - No contiene \contribtype{2}
# Sin cambios: 2200.tex - No contiene \contribtype{2}
# Sin cambios: 2104.tex - No contiene \contribtype{2}
# Modificado: 2304.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2305.tex - No contiene \contribtype{2}
# Sin cambios: 2240.tex - No contiene \contribtype{2}
# Sin cambios: 2092.tex - No contiene \contribtype{2}
# Sin cambios: 2139.tex - No contiene \contribtype{2}
# Sin cambios: 2229.tex - No contiene \contribtype{2}
# Sin cambios: 2236.tex - No contiene \contribtype{2}
# Modificado: 2303.tex - \contribtype{2} cambiado a \contribtype{1}
# Modificado: 2085.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2274.tex - No contiene \contribtype{2}
# Sin cambios: 2084.tex - No contiene \contribtype{2}
# Sin cambios: 2190.tex - No contiene \contribtype{2}
# Sin cambios: 2174.tex - No contiene \contribtype{2}
# Sin cambios: 2189.tex - No contiene \contribtype{2}
# Sin cambios: 2202.tex - No contiene \contribtype{2}
# Modificado: 2201.tex - \contribtype{2} cambiado a \contribtype{1}
# Modificado: 2150.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2105.tex - No contiene \contribtype{2}
# Sin cambios: 2267.tex - No contiene \contribtype{2}
# Sin cambios: 2159.tex - No contiene \contribtype{2}
# Sin cambios: 2115.tex - No contiene \contribtype{2}
# Sin cambios: 2169.tex - No contiene \contribtype{2}
# Sin cambios: 2276.tex - No contiene \contribtype{2}
# Modificado: 2278.tex - \contribtype{2} cambiado a \contribtype{1}
# Sin cambios: 2203.tex - No contiene \contribtype{2}
# Sin cambios: 2185.tex - No contiene \contribtype{2}
# Sin cambios: 2256.tex - No contiene \contribtype{2}
# Sin cambios: 2170.tex - No contiene \contribtype{2}
# Sin cambios: 2205.tex - No contiene \contribtype{2}
# Sin cambios: 2271.tex - No contiene \contribtype{2}
# Sin cambios: 2195.tex - No contiene \contribtype{2}
# Sin cambios: 2292.tex - No contiene \contribtype{2}
# Modificado: 2288.tex - \contribtype{2} cambiado a \contribtype{1}
# Proceso completado.
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:32: SyntaxWarning: invalid escape sequence '\c'
# <>:34: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\526314955.py:32: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{{2}} cambiado a \contribtype{{1}}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\526314955.py:32: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Modificado: {nombre_archivo} - \contribtype{{2}} cambiado a \contribtype{{1}}")
# C:\Users\maria\AppData\Local\Temp\ipykernel_18472\526314955.py:34: SyntaxWarning: invalid escape sequence '\c'
#   print(f"Sin cambios: {nombre_archivo} - No contiene \contribtype{{2}}")
