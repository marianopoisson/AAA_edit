# %%
import checkBAAA
import glob
import os, sys, tarfile
import shutil

# %%
# tar extract

def extract(tar_url, extract_path='./TGZs-iniciales/extracted/'):
    print(tar_url)
    tar = tarfile.open(tar_url, 'r')
    for item in tar:
        tar.extract(item, extract_path)
        if item.name.find(".tgz") != -1 or item.name.find(".tar") != -1:
            extract(item.name, "./" + item.name[:item.name.rfind('/')])

# %%
lista=[]
for st in glob.glob('./TGZs-iniciales/*.tgz'):
    lista.append(st[17:20])

# %%
lista
# Out:
# ['858',
#  '859',
#  '863',
#  '864',
#  '865',
#  '866',
#  '868',
#  '869',
#  '870',
#  '871',
#  '872',
#  '873',
#  '874',
#  '875',
#  '876',
#  '877',
#  '878',
#  '879',
#  '880',
#  '881',
#  '882',
#  '883',
#  '884',
#  '885',
#  '886',
#  '887',
#  '888',
#  '889',
#  '890',
#  '891',
#  '892',
#  '893',
#  '894',
#  '895',
#  '896',
#  '897',
#  '898',
#  '899',
#  '900',
#  '901',
#  '902',
#  '903',
#  '904',
#  '905',
#  '906',
#  '907',
#  '908',
#  '909',
#  '910',
#  '911',
#  '912',
#  '913',
#  '915',
#  '916',
#  '917',
#  '918',
#  '920',
#  '921',
#  '922',
#  '923',
#  '924',
#  '925',
#  '927',
#  '928',
#  '929',
#  '931',
#  '932',
#  '933']

# %% [markdown]
# # Parte 1

# %%
#recover cites from text and bib

def RecoverCites(text, bib=None):
    cites=[]
    for i in text:
        x=i.find("\\cite")
        if x >=0:
            cites.append(i)
    ref=[]
    for c in cites:
        start = 0
        
        while start>=0:
            start = c.find("\\cite", start)
            if start ==-1:
                continue
            j=c[start:].find("{")
            k=c[start:].find("}")
            ref.append(c[start+j+1:start+k])
            start += 5   

    ref0=[]
    for i in ref:
        x=i.split(',')
        for h in x:
            ref0.append(h.replace(' ',''))
    
    ref=ref0
    
    bib=glob.glob(bib)
    f = open(bib[0],'r',encoding=encoding)
    bibtex = f.read().split('@')
    f.close()
    
    
    dcites=[]

    for i in ref:
        j=0
        for c in bibtex:
            j=j+1
            x=c.find(i)
            if x >0:
                dcites.append(j)
    print('# de citas: ',len(set(dcites)))
    
    for p,d in enumerate(set(dcites)):
        bb=bibtex[d-1].split('\n')
        y=bibtex[d-1].find('year')
        x=bibtex[d-1].find('thor')
        startau=bibtex[d-1].find('=',x)
        endau=bibtex[d-1].find(',',x)
        
        starty=bibtex[d-1].find('=',y)
        endy=bibtex[d-1].find(',',y)
    
        print(p+1,bibtex[d-1][startau+1:endau],'...,',bibtex[d-1][starty+1:endy])

# %%
lista[0]
# Out:
# '896'

# %%
for name in ['918']:
#for name in lista:
    
    old_stdout = sys.stdout
    print(name+'----------------------------')
    
    
    try:
    
        log_file = open('./TGZs-iniciales/'+name+'.log',"w", encoding="utf-8")
    
        sys.stdout = log_file
        extract(glob.glob('./TGZs-iniciales/'+name+'*.tgz')[0])
        for file_path in glob.glob('./TGZs-iniciales/extracted/*.sty'):
            if os.path. exists(file_path):
               # print('removed: '+file_path)
                os.remove(file_path)
    
        shutil.copy('baaa.cls','./TGZs-iniciales/extracted')
        shutil.copy('logoAAA.pdf','./TGZs-iniciales/extracted')
        shutil.copy('baaa.bst','./TGZs-iniciales/extracted')
    
        os.chdir('./TGZs-iniciales/extracted')
        tex=glob.glob('./*.tex')
        bib=glob.glob('./*.bib')
        os.rename(tex[0], str(name)+'.tex')
     #   shutil.move(tex[0], str(name)+'.tex')
        tex=glob.glob('./*.tex')
        
        
        os.system("pdflatex "+tex[0])
        aux=glob.glob('./*.aux')
        
        os.system("bibtex "+str(name))
        os.system("pdflatex "+tex[0])
        os.system("pdflatex "+tex[0])
    
        shutil.copy(tex[0], '../tex0')
        bibf = open(bib[0], encoding="utf8")
        bibtex = bibf.read()
        bibf.close()
        
        
        os.chdir('../..')
    
    
       # shutil.copy(pdf[0], './TGZs-iniciales/pdfs')
    
        tex=glob.glob('./TGZs-iniciales/extracted/*.tex')
        bib=glob.glob('./TGZs-iniciales/extracted/*.bib')
        pdf=glob.glob('./TGZs-iniciales/extracted/'+name+'.pdf')
        
        shutil.copy(pdf[0], './TGZs-iniciales/pdfs')
        
        if len(tex) >1 :
            print('multiple tex')
        if len(tex) ==0:
            print('no tex found')
       # sys.argv[1]=tex
        # %run checkBAAA {tex[0]}
        RecoverCites(text,bib=bib[0])
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)
    
        sys.stdout = old_stdout
    
        log_file.close()

    except:
        sys.stdout = old_stdout
        print('error processing: '+name+' file')
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)
# Out:
# 918----------------------------

# %%
os.chdir('../..')

# %% [markdown]
# # Parte 2

# %%
import shutil
log_file = open('./TGZs-iniciales/afill4.log',"w", encoding="utf-8")
old_stdout = sys.stdout
sys.stdout = log_file

for name in ['918']:
#for name in lista:
    
 #   old_stdout = sys.stdout
    print(name+'----------------------------')
    
    
    try:
    
   #     log_file = open('./TGZs-iniciales/'+name+'.log',"w", encoding="utf-8")
    
    #    sys.stdout = log_file
        extract(glob.glob('./TGZs-iniciales/'+name+'*.tgz')[0])
     #   extract(glob.glob('./TGZs-iniciales/tgz1/'+name+'*.tgz')[0])
        

       # shutil.copy('./TGZs-iniciales/tex1/'+name+'.tex','./TGZs-iniciales/extracted')
        
        os.chdir('./TGZs-iniciales/extracted')
        for file_path in ["baaa.bst","baaa.cls","BAAA_afiliaciones.txt","logoAAA.pdf"]:
            if os.path. exists(file_path):
               # print('removed: '+file_path)
                os.remove(file_path)
        for file_path in glob.glob('./*.sty'):
            if os.path. exists(file_path):
               # print('removed: '+file_path)
                os.remove(file_path)
        
        tex=glob.glob('./*.tex')
        bib=glob.glob('./*.bib')
        os.rename(tex[0], str(name)+'.tex')
     #   shutil.move(tex[0], str(name)+'.tex')
        shutil.copy('../tex1/'+name+'.tex','.')
        files0 = glob.glob('./*')
        os.mkdir('./ext')
        
        for f in files0:
            shutil.copy(f,'./ext')

        shutil.copy('../../baaa.cls','.')
        shutil.copy('../../logoAAA.pdf','.')
        shutil.copy('../../baaa.bst','.')
        
        tex=glob.glob('./*.tex')
        
        
        os.system("pdflatex "+tex[0])
        aux=glob.glob('./*.aux')
        
        os.system("bibtex "+str(name))
        os.system("pdflatex "+tex[0])
        os.system("pdflatex "+tex[0])
    
       # shutil.copy(tex[0], '../tex0')
    #    bibf = open(bib[0], encoding="utf8")
     #   bibtex = bibf.read()
      #  bibf.close()
        pdf=glob.glob('./'+name+'.pdf')
        shutil.copy(pdf[0], './ext')
        shutil.copy(pdf[0], '../pdfs1')
        
        os.chdir('./ext')
        files1 = glob.glob('./*')
        
        tar = tarfile.open(name+".tgz", "w:gz")
        for f in files1:
            tar.add(f)
        tar.close()
        tgz=glob.glob('./*.tgz')
        shutil.copy(tgz[0],'../../tgz2/')  
        
        os.chdir('../../..')
    
    
       # shutil.copy(pdf[0], './TGZs-iniciales/pdfs')

        
    
        tex=glob.glob('./TGZs-iniciales/extracted/*.tex')
     #   bib=glob.glob('./TGZs-iniciales/extracted/*.bib')
   #     pdf=glob.glob('./TGZs-iniciales/extracted/'+name+'.pdf')
        
    #    shutil.copy(pdf[0], './TGZs-iniciales/pdfs1')
        
        if len(tex) >1 :
            print('multiple tex')
        if len(tex) ==0:
            print('no tex found')
       # sys.argv[1]=tex
        # %run checkBAAA {tex[0]}
     #   RecoverCites(text,bib=bib[0])
        shutil.rmtree('./TGZs-iniciales/extracted/ext')  # remove dir and all contains
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)
    
 #       sys.stdout = old_stdout
   #     log_file.close()    


    except:
        sys.stdout = old_stdout
        print('error processing: '+name+' file')
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)

sys.stdout = old_stdout        
log_file.close()

# %%
import shutil
log_file = open('./TGZs-iniciales/afill3.log',"w", encoding="utf-8")
old_stdout = sys.stdout
sys.stdout = log_file

#for name in ['858']:
for name in lista:
    
 #   old_stdout = sys.stdout
    print(name+'----------------------------')
    
    
    try:
    
   #     log_file = open('./TGZs-iniciales/'+name+'.log',"w", encoding="utf-8")
    
    #    sys.stdout = log_file
       # extract(glob.glob('./TGZs-iniciales/'+name+'*.tgz')[0])
        extract(glob.glob('./TGZs-iniciales/tgz2/'+name+'*.tgz')[0])
        

       # shutil.copy('./TGZs-iniciales/tex1/'+name+'.tex','./TGZs-iniciales/extracted')
            
    
       # shutil.copy(pdf[0], './TGZs-iniciales/pdfs')

        
    
        tex=glob.glob('./TGZs-iniciales/extracted/*.tex')
     #   bib=glob.glob('./TGZs-iniciales/extracted/*.bib')
   #     pdf=glob.glob('./TGZs-iniciales/extracted/'+name+'.pdf')
        
    #    shutil.copy(pdf[0], './TGZs-iniciales/pdfs1')
        
        if len(tex) >1 :
            print('multiple tex')
        if len(tex) ==0:
            print('no tex found')
       # sys.argv[1]=tex
        # %run checkBAAA {tex[0]}
     #   RecoverCites(text,bib=bib[0])
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)
    
 #       sys.stdout = old_stdout
   #     log_file.close()    


    except:
        sys.stdout = old_stdout
        print('error processing: '+name+' file')
        files = glob.glob('./TGZs-iniciales/extracted/*')
        for f in files:
            os.remove(f)

sys.stdout = old_stdout        
log_file.close()

# %% [markdown]
# # Parte 3

# %%
import shutil
#log_file = open('./TGZs-iniciales/afill4.log',"w", encoding="utf-8")
#old_stdout = sys.stdout
#sys.stdout = log_file

#for name in ['918']:
for name in lista:
    
 #   old_stdout = sys.stdout
    print(name+'----------------------------')
    
    
    try:
    
   #     log_file = open('./TGZs-iniciales/'+name+'.log',"w", encoding="utf-8")
    
    #    sys.stdout = log_file
        extract(glob.glob('./TGZs-iniciales/'+name+'*.tgz')[0])
     #   extract(glob.glob('./TGZs-iniciales/tgz1/'+name+'*.tgz')[0])
        #shutil.copy('./TGZs-iniciales/extracted/'+name+'.tex','./TGZs-iniciales/extracted')     

       # shutil.copy('./TGZs-iniciales/tex1/'+name+'.tex','./TGZs-iniciales/extracted')
        
        os.chdir('./TGZs-iniciales/extracted/'+name)
        for file_path in ["baaa.bst","baaa.cls","BAAA_afiliaciones.txt","logoAAA.pdf"]:
            if os.path. exists(file_path):
               # print('removed: '+file_path)
                os.remove(file_path)
        for file_path in glob.glob('./*.sty'):
            if os.path. exists(file_path):
               # print('removed: '+file_path)
                os.remove(file_path)
        
        tex=glob.glob('./*.tex')
        bib=glob.glob('./*.bib')
     #   shutil.move(tex[0], str(name)+'.tex')
        files0 = glob.glob('./*')
        os.mkdir('./ext')
        
        for f in files0:
            shutil.copy(f,'./ext')

        shutil.copy('../../../baaa.cls','.')
        shutil.copy('../../../logoAAA.pdf','.')
        shutil.copy('../../../baaa.bst','.')
        
        tex=glob.glob('./*.tex')
        
        
        os.system("pdflatex "+tex[0])
        aux=glob.glob('./*.aux')
        
        os.system("bibtex "+str(name))
        os.system("pdflatex "+tex[0])
        os.system("pdflatex "+tex[0])
    
       # shutil.copy(tex[0], '../tex0')
    #    bibf = open(bib[0], encoding="utf8")
     #   bibtex = bibf.read()
      #  bibf.close()
        pdf=glob.glob('./'+name+'.pdf')
        shutil.copy(pdf[0], './ext')
        shutil.copy(pdf[0], '../pdfs3')
        
        os.chdir('./ext')
        files1 = glob.glob('./*')
        
        tar = tarfile.open(name+".tgz", "w:gz")
        for f in files1:
            tar.add(f)
        tar.close()
        tgz=glob.glob('./*.tgz')
        shutil.copy(tgz[0],'../../../tgz3/')  
        
        os.chdir('../../../..')
    
    
       # shutil.copy(pdf[0], './TGZs-iniciales/pdfs')

        
    
        tex=glob.glob('./TGZs-iniciales/extracted/*.tex')
     #   bib=glob.glob('./TGZs-iniciales/extracted/*.bib')
   #     pdf=glob.glob('./TGZs-iniciales/extracted/'+name+'.pdf')
        
    #    shutil.copy(pdf[0], './TGZs-iniciales/pdfs1')
        
       # sys.argv[1]=tex
 #       %run checkBAAA {tex[0]}
     #   RecoverCites(text,bib=bib[0])
        shutil.rmtree('./TGZs-iniciales/extracted/'+name)  # remove dir and all contains
      #  files = glob.glob('./TGZs-iniciales/extracted/*')
      #  for f in files:
      #      os.remove(f)
    
 #       sys.stdout = old_stdout
   #     log_file.close()    


    except:
     #   sys.stdout = old_stdout
        print('error processing: '+name+' file')
        shutil.rmtree('./TGZs-iniciales/extracted/'+name)


#sys.stdout = old_stdout        
#log_file.close()
# Out:
# 858----------------------------
# ./TGZs-iniciales\858_updated.tgz
# error processing: 858 file
# 859----------------------------
# ./TGZs-iniciales\859_updated.tgz
# error processing: 859 file
# 863----------------------------
# ./TGZs-iniciales\863_updated.tgz
# error processing: 863 file
# 864----------------------------
# ./TGZs-iniciales\864_updated.tgz
# error processing: 864 file
# 865----------------------------
# ./TGZs-iniciales\865_updated.tgz
# error processing: 865 file
# 866----------------------------
# ./TGZs-iniciales\866_updated.tgz
# error processing: 866 file
# 868----------------------------
# ./TGZs-iniciales\868_updated.tgz
# error processing: 868 file
# 869----------------------------
# ./TGZs-iniciales\869_updated.tgz
# error processing: 869 file
# 870----------------------------
# ./TGZs-iniciales\870_updated.tgz
# error processing: 870 file
# 871----------------------------
# ./TGZs-iniciales\871_updated.tgz
# error processing: 871 file
# 872----------------------------
# ./TGZs-iniciales\872_updated.tgz
# error processing: 872 file
# 873----------------------------
# ./TGZs-iniciales\873_updated.tgz
# error processing: 873 file
# 874----------------------------
# ./TGZs-iniciales\874_updated.tgz
# error processing: 874 file
# 875----------------------------
# ./TGZs-iniciales\875_updated.tgz
# error processing: 875 file
# 876----------------------------
# ./TGZs-iniciales\876_updated.tgz
# error processing: 876 file
# 877----------------------------
# ./TGZs-iniciales\877_updated.tgz
# error processing: 877 file
# 878----------------------------
# ./TGZs-iniciales\878_updated.tgz
# error processing: 878 file
# 879----------------------------
# ./TGZs-iniciales\879_updated.tgz
# error processing: 879 file
# 880----------------------------
# ./TGZs-iniciales\880_updated.tgz
# error processing: 880 file
# 881----------------------------
# ./TGZs-iniciales\881_updated.tgz
# error processing: 881 file
# 882----------------------------
# ./TGZs-iniciales\882_updated.tgz
# error processing: 882 file
# 883----------------------------
# ./TGZs-iniciales\883_updated.tgz
# error processing: 883 file
# 884----------------------------
# ./TGZs-iniciales\884_updated.tgz
# error processing: 884 file
# 885----------------------------
# ./TGZs-iniciales\885_updated.tgz
# error processing: 885 file
# 886----------------------------
# ./TGZs-iniciales\886_updated.tgz
# error processing: 886 file
# 887----------------------------
# ./TGZs-iniciales\887_updated.tgz
# error processing: 887 file
# 888----------------------------
# ./TGZs-iniciales\888_updated.tgz
# error processing: 888 file
# 889----------------------------
# ./TGZs-iniciales\889_updated.tgz
# error processing: 889 file
# 890----------------------------
# ./TGZs-iniciales\890_updated.tgz
# error processing: 890 file
# 891----------------------------
# ./TGZs-iniciales\891_updated.tgz
# error processing: 891 file
# 892----------------------------
# ./TGZs-iniciales\892_updated.tgz
# error processing: 892 file
# 893----------------------------
# ./TGZs-iniciales\893_updated.tgz
# error processing: 893 file
# 894----------------------------
# ./TGZs-iniciales\894_updated.tgz
# error processing: 894 file
# 895----------------------------
# ./TGZs-iniciales\895_updated.tgz
# error processing: 895 file
# 896----------------------------
# ./TGZs-iniciales\896_updated.tgz
# error processing: 896 file
# 897----------------------------
# ./TGZs-iniciales\897_updated.tgz
# error processing: 897 file
# 898----------------------------
# ./TGZs-iniciales\898_updated.tgz
# error processing: 898 file
# 899----------------------------
# ./TGZs-iniciales\899_updated.tgz
# error processing: 899 file
# 900----------------------------
# ./TGZs-iniciales\900_updated.tgz
# error processing: 900 file
# 901----------------------------
# ./TGZs-iniciales\901_updated.tgz
# error processing: 901 file
# 902----------------------------
# ./TGZs-iniciales\902_updated.tgz
# error processing: 902 file
# 903----------------------------
# ./TGZs-iniciales\903_updated.tgz
# error processing: 903 file
# 904----------------------------
# ./TGZs-iniciales\904_updated.tgz
# error processing: 904 file
# 905----------------------------
# ./TGZs-iniciales\905_updated.tgz
# error processing: 905 file
# 906----------------------------
# ./TGZs-iniciales\906_updated.tgz
# error processing: 906 file
# 907----------------------------
# ./TGZs-iniciales\907_updated.tgz
# error processing: 907 file
# 908----------------------------
# ./TGZs-iniciales\908_updated.tgz
# error processing: 908 file
# 909----------------------------
# ./TGZs-iniciales\909_updated.tgz
# error processing: 909 file
# 910----------------------------
# ./TGZs-iniciales\910_updated.tgz
# error processing: 910 file
# 911----------------------------
# ./TGZs-iniciales\911_updated.tgz
# error processing: 911 file
# 912----------------------------
# ./TGZs-iniciales\912_updated.tgz
# error processing: 912 file
# 913----------------------------
# ./TGZs-iniciales\913_updated.tgz
# error processing: 913 file
# 915----------------------------
# ./TGZs-iniciales\915_updated.tgz
# error processing: 915 file
# 916----------------------------
# ./TGZs-iniciales\916_updated.tgz
# error processing: 916 file
# 917----------------------------
# ./TGZs-iniciales\917_updated.tgz
# error processing: 917 file
# 918----------------------------
# ./TGZs-iniciales\918_updated.tgz
# error processing: 918 file
# 920----------------------------
# ./TGZs-iniciales\920_updated.tgz
# error processing: 920 file
# 921----------------------------
# ./TGZs-iniciales\921_updated.tgz
# error processing: 921 file
# 922----------------------------
# ./TGZs-iniciales\922_updated.tgz
# error processing: 922 file
# 923----------------------------
# ./TGZs-iniciales\923_updated.tgz
# error processing: 923 file
# 924----------------------------
# ./TGZs-iniciales\924_updated.tgz
# error processing: 924 file
# 925----------------------------
# ./TGZs-iniciales\925_updated.tgz
# error processing: 925 file
# 927----------------------------
# ./TGZs-iniciales\927_updated.tgz
# error processing: 927 file
# 928----------------------------
# ./TGZs-iniciales\928_updated.tgz
# error processing: 928 file
# 929----------------------------
# ./TGZs-iniciales\929_updated.tgz
# error processing: 929 file
# 931----------------------------
# ./TGZs-iniciales\931_updated.tgz
# error processing: 931 file
# 932----------------------------
# ./TGZs-iniciales\932_updated.tgz
# error processing: 932 file
# 933----------------------------
# ./TGZs-iniciales\933_updated.tgz
# error processing: 933 file
